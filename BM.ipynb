# %%
from dwavebinarycsp import stitch, irreducible_components, Constraint
import operator

def squeeze_same_results(results):
    squeezed_results = [results[0]]
    for item in results[1:]:
        for squeezed_item in squeezed_results:
            if item['results'] == squeezed_item['results']:
                if item['min_energy'] < squeezed_item['min_energy']:
                    squeezed_item['min_energy'] = item['min_energy']
                    squeezed_item['occurrences'] = item['occurrences']
                elif item['min_energy'] == squeezed_item['min_energy']:
                    squeezed_item['occurrences'] += item['occurrences']
                break
        else:
            squeezed_results.append(item)
    return squeezed_results


def parse_result(response):
    parsed_response = {}
    for datum in response.data(['sample', 'energy', 'num_occurrences']):
        key = (tuple(dict(datum.sample).items()), float(datum.energy))
        if key in parsed_response:
            parsed_response[key] = (datum.sample, parsed_response[key][1] + datum.num_occurrences)
        else:
            parsed_response[key] = (datum.sample, datum.num_occurrences)

    num_runs = sum([parsed_response[key][1] for key in parsed_response])
    results = []
    for key in parsed_response:
        results.append({
            'results': parsed_response[key][0],
            'min_energy': key[1],
            'occurrences': parsed_response[key][1] / num_runs * 100
        })
    return squeeze_same_results(results)


def get_response(response, embedding=None, qubits=None):
    results = parse_result(response)
    if embedding is not None:
        embedding_results = []
        for item in results:
            embedding_item = {
                'results': {},
                'min_energy': item['min_energy'],
                'occurrences': item['occurrences']
            }
            for A in embedding:
                embedding_item['results'][A] = sum([item['results'][qubit] for qubit in embedding[A]])
                embedding_item['results'][A] /= len(embedding[A])
                embedding_item['results'][A] = round(embedding_item['results'][A], 2)
            embedding_results.append(embedding_item)
        results = squeeze_same_results(embedding_results)
    if qubits is not None:
        new_results = []
        for item in results:
            new_results.append({
                'results': {key: item['results'][key] for key in qubits},
                'min_energy': item['min_energy'],
                'occurrences': item['occurrences']
            })
        results = new_results
    return squeeze_same_results(results)


def print_response(response, embedding=None, qubits=None):
    results = get_response(response, embedding=embedding, qubits=qubits)
    for item in results:
        print(item['results'], "Minimum energy: ", item['min_energy'],
              f"Occurrences: {item['occurrences']:.2f}%")


# TODO Need refactoring
def get_response_only_minimal(response, embedding=None, qubits=None):
    results = get_response(response, embedding=embedding, qubits=qubits)
    min_energy = min(map(lambda x: x['min_energy'], results))
    results = list(filter(lambda x: x['min_energy'] == min_energy, results))
    return squeeze_same_results(results)


def print_response_only_minimal(response, embedding=None, qubits=None):
    results_only_minimal = get_response_only_minimal(response, embedding=embedding,
                                                     qubits=qubits)
    for item in results_only_minimal:
        print(item['results'], "Minimum energy: ", item['min_energy'],
              f"Occurrences: {item['occurrences']:.2f}%")
    print()
    total = sum([item['occurrences'] for item in results_only_minimal])
    print(f"Total: {total:.2f}%")


import dwavebinarycsp
import dimod
from collections import Counter
from dwave.system.composites import FixedEmbeddingComposite
from dwave.system.samplers import DWaveSampler

def Qubo(weights, v_all, qbits_Num):
    #Q = {('x0','x0'): -1, ('x0','x1'): 2, ('x1', 'x0'): 0, ('x1','x1'): -1}
    Q = dict()
    for i in range(qbits_Num):
        for j in range(qbits_Num):
            Q[(v_all[i], v_all[j])] = weights[i][j]
    return Q


class Boltzman:
    weights = [] #w[i][j]
    q_in = {} #List explicitly specifying each allowed configuration as a tuple q_in = {(0, 0, 1)}
    number_in = 100
    v_in = [] # v_in = ['v0', 'v1'] or v_in = [0, 1]
    v_all = []
    number_out = 100
    embedding = ()
    qbits_Num = 200 # = number_out + number_in
    def run(self):
        # Create a binary constraint satisfaction problem
        csp = dwavebinarycsp.ConstraintSatisfactionProblem(dwavebinarycsp.BINARY)
        csp.add_constraint(self.q_in, self.v_in)
        bqm =  dwavebinarycsp.stitch(csp, min_classical_gap=2.0, max_graph_size=8) #csp to BinaryQuadraticModel, penaltymodel required(if there are mpre then 2 variables)
        QUBO_CSP = dimod.BinaryQuadraticModel.to_qubo(bqm)
        QUBO_weights = Qubo(self.weights, self.v_all, self.qbits_Num)
        
        #bqm_w = dimod.BinaryQuadraticModel.from_qubo(QUBO_weights)

        QUBO_sum_Counter = (Counter(QUBO_weights)) + Counter(QUBO_CSP[0]))
        QUBO_sum = dict(QUBO_sum_Counter)
        samp = DWaveSampler()
        sampler_embedded = FixedEmbeddingComposite(samp, self.embedding)
        response_BM = sampler_embedded.sample_qubo(QUBO_sum, num_reads= 5000)
        Solution = get_response_only_minimal(response_BM)
    
        return Solution
# Out:
#   File "<ipython-input-59-1feb256d1949>", line 128
#     QUBO_sum_Counter = (Counter(QUBO_weights)) + Counter(QUBO_CSP[0]))
#                                                                      ^
# SyntaxError: invalid syntax

# %%
from dwave.cloud import Client
client = Client.from_config(token = '')
client.get_solvers()
r = Boltzman()
r.weights = [[0, 3, 1], [0, 0, 2], [0, 0, 0]]
r.q_in = {(0, 1)}
r.v_in = ['0', '1']
r.v_all = ['0', '1', '2']
r.embedding ={'0': {0}, '1':{4}, '2':{3,7}}
r.qbits_Num = 3
r.run()
# Out:
# {('0', '0'): 0, ('0', '1'): 3, ('0', '2'): 1, ('1', '0'): 0, ('1', '1'): 0, ('1', '2'): 2, ('2', '0'): 0, ('2', '1'): 0, ('2', '2'): 0} {('0', '0'): 2, ('1', '1'): -2}
# ---------------------------------------------------------------------------
# SolverFailureError                        Traceback (most recent call last)
# <ipython-input-60-b9bf3cd7a5a1> in <module>
#       9 r.embedding ={'0': {0}, '1':{4}, '2':{3,7}}
#      10 r.qbits_Num = 3
# ---> 11 r.run()
#
# <ipython-input-57-4733c9f106aa> in run(self)
#     131         samp = DWaveSampler()
#     132         sampler_embedded = FixedEmbeddingComposite(samp, self.embedding)
# --> 133         response_BM = sampler_embedded.sample_qubo(QUBO_sum, num_reads= 5000)
#     134         Solution = get_response_only_minimal(response_BM)
#     135
#
# ~\Anaconda2\envs\py36\lib\site-packages\dimod\core\sampler.py in sample_qubo(self, Q, **parameters)
#     177         """
#     178         bqm = BinaryQuadraticModel.from_qubo(Q)
# --> 179         return self.sample(bqm, **parameters)
#
# ~\Anaconda2\envs\py36\lib\site-packages\dimod\decorators.py in new_f(sampler, bqm, **kwargs)
#     151             raise BinaryQuadraticModelStructureError("given bqm does not match the sampler's structure")
#     152
# --> 153         return f(sampler, bqm, **kwargs)
#     154
#     155     return new_f
#
# ~\Anaconda2\envs\py36\lib\site-packages\dwave\system\composites\embedding.py in sample(self, bqm, chain_strength, chain_break_fraction, **parameters)
#     406             parameters['initial_state'] = _embed_state(embedding, parameters['initial_state'])
#     407
# --> 408         response = child.sample(bqm_embedded, **parameters)
#     409
#     410         return unembed_sampleset(response, embedding, source_bqm=bqm,
#
# ~\Anaconda2\envs\py36\lib\site-packages\dimod\core\sampler.py in sample(self, bqm, **parameters)
#     155                 Q, offset = bqm.to_qubo()
#     156                 sampleset = self.sample_qubo(Q, **parameters)
# --> 157                 sampleset.record.energy += offset
#     158                 return sampleset
#     159             else:
#
# ~\Anaconda2\envs\py36\lib\site-packages\dimod\sampleset.py in record(self)
#     662         """
#     663         if hasattr(self, '_future'):
# --> 664             self._resolve_future()
#     665         return self._record
#     666
#
# ~\Anaconda2\envs\py36\lib\site-packages\dimod\sampleset.py in _resolve_future(self)
#     526
#     527     def _resolve_future(self):
# --> 528         samples = self._result_hook(self._future)
#     529         self.__init__(samples.record, samples.variables, samples.info, samples.vartype)
#     530         del self._future
#
# ~\Anaconda2\envs\py36\lib\site-packages\dwave\system\samplers\dwave_sampler.py in _hook(computation)
#     415 def _result_to_response_hook(variables, vartype):
#     416     def _hook(computation):
# --> 417         result = computation.result()
#     418
#     419         # get the samples. The future will return all spins so filter for the ones in variables
#
# ~\Anaconda2\envs\py36\lib\site-packages\dwave\cloud\computation.py in result(self)
#     491
#     492         """
# --> 493         self._load_result()
#     494         return self._result
#     495
#
# ~\Anaconda2\envs\py36\lib\site-packages\dwave\cloud\computation.py in _load_result(self)
#     656             if self.error is not None:
#     657                 if self._exc_info is not None:
# --> 658                     six.reraise(*self._exc_info)
#     659                 if isinstance(self.error, Exception):
#     660                     raise self.error
#
# ~\Anaconda2\envs\py36\lib\site-packages\six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# ~\Anaconda2\envs\py36\lib\site-packages\dwave\cloud\client.py in _handle_problem_status(self, message, future)
#    1002             # Handle errors in batch mode
#    1003             if 'error_code' in message and 'error_msg' in message:
# -> 1004                 raise SolverFailureError(message['error_msg'])
#    1005
#    1006             if 'status' not in message:
#
# SolverFailureError: Problem not accepted because user kirill.parshukov.14@gmail.com has no remaining quota in project DEV
